# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (18,6)

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Show current working directory
print("Current Directory:", os.getcwd())
print("Files in this directory:")
print(os.listdir())

# CHANGE THESE NAMES if needed based on printed list
img_left_path   = "pic1.jpeg"
img_center_path = "pic2.jpeg"
img_right_path  = "pic3.jpeg"

# Load images
img_left   = cv2.imread(img_left_path)
img_center = cv2.imread(img_center_path)
img_right  = cv2.imread(img_right_path)

# Check if any image failed
if img_left is None:
    print(f"❌ Could not load {img_left_path}")
if img_center is None:
    print(f"❌ Could not load {img_center_path}")
if img_right is None:
    print(f"❌ Could not load {img_right_path}")

# Stop execution if any image missing
if img_left is None or img_center is None or img_right is None:
    raise FileNotFoundError("One or more images not found. Check filenames above.")

# Convert to RGB for matplotlib
img_left   = cv2.cvtColor(img_left, cv2.COLOR_BGR2RGB)
img_center = cv2.cvtColor(img_center, cv2.COLOR_BGR2RGB)
img_right  = cv2.cvtColor(img_right, cv2.COLOR_BGR2RGB)

# Display images
plt.figure(figsize=(15,5))
plt.subplot(1,3,1); plt.imshow(img_left); plt.title("Left"); plt.axis("off")
plt.subplot(1,3,2); plt.imshow(img_center); plt.title("Center"); plt.axis("off")
plt.subplot(1,3,3); plt.imshow(img_right); plt.title("Right"); plt.axis("off")
plt.show()
# Out:
# Current Directory: d:\computer vision assinments
# Files in this directory:
# ['.git', '.gitignore', 'cv_env', 'images', 'new.ipynb', 'panorama.ipynb']
# ❌ Could not load pic1.jpeg
# ❌ Could not load pic2.jpeg
# ❌ Could not load pic3.jpeg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 30
#      28 # Stop execution if any image missing
#      29 if img_left is None or img_center is None or img_right is None:
# ---> 30     raise FileNotFoundError("One or more images not found. Check filenames above.")
#      32 # Convert to RGB for matplotlib
#      33 img_left   = cv2.cvtColor(img_left, cv2.COLOR_BGR2RGB)
#
# FileNotFoundError: One or more images not found. Check filenames above.
